# %%
import pandas as pd

# %%
data = pd.read_csv(r"Auto-Ria-project/cars_dataset.csv")
data
# Out:
#              ID           Mark     Model  Year  Price_USD  Mileage  Engine  \
# 0       2059468           Opel     Omega  1990       1900      300       0
# 1      39346065  Mercedes-Benz     eVito  2021      27800      257       0
# 2      38511410     Volkswagen   E-Tharu  2020      18000       31       0
# 3       2057310          Skoda   Octavia  2007      14500       67       0
# 4      39587514            BMW  5 Series  2017      36200      129       0
# ...         ...            ...       ...   ...        ...      ...     ...
# 18888   2023787           Fiat     Bravo  1997       5000      211       0
# 18889   2001100     Mitsubishi    Lancer  2007      17000       31       0
# 18890   2001099        Peugeot   Partner  2004       8000      115       0
# 18891   2000535            ВАЗ      2107  2006       4500        1       0
# 18892   1997552     Volkswagen      Polo  2000       7150      132       0
#
#                   Fuel           Gearbox
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18893 entries, 0 to 18892
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         18893 non-null  int64
#  1   Mark       18805 non-null  str
#  2   Model      18039 non-null  str
#  3   Year       18893 non-null  int64
#  4   Price_USD  18893 non-null  int64
#  5   Mileage    18893 non-null  int64
#  6   Engine     18893 non-null  int64
#  7   Fuel       18893 non-null  str
#  8   Gearbox    18893 non-null  str
# dtypes: int64(5), str(4)
# memory usage: 1.3 MB

# %%
data['Gearbox'].value_counts()
# Out:
# Gearbox
# Автомат             9677
# Ручна / Механіка    6233
# Не вказано          1067
# Типтронік            653
# Редуктор             513
# Варіатор             508
# Робот                242
# Name: count, dtype: int64

# %%
data['Mark'].value_counts()
# Out:
# Mark
# Volkswagen       2041
# BMW              1442
# Audi             1410
# Mercedes-Benz    1196
# Ford              910
#                  ...
# Kawasaki            1
# AION                1
# McLaren             1
# МТЗ                 1
# СМК                 1
# Name: count, Length: 163, dtype: int64

# %%
data.query("Mark == 'ВАЗ'")['Price_USD'].mean()
# Out:
# np.float64(2934.147313691508)
